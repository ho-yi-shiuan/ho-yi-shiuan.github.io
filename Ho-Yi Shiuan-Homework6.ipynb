# %%
import pandas as pd
import bqplot
from bqplot import pyplot as plt
import matplotlib.pyplot as plt
from bqplot import Tooltip
import numpy as np
import ipywidgets

# %%
ufo = pd.read_csv("https://uiuc-ischool-dataviz.github.io/is445_AOUAOG_fall2021/week02/data/building_inventory.csv")

# %%
ufo
# Out:
#                            Agency Name  \
# 0      Department of Natural Resources
# 1      Department of Natural Resources
# 2      Department of Natural Resources
# 3      Department of Natural Resources
# 4      Department of Natural Resources
# ...                                ...
# 8857      Department of Transportation
# 8858      Department of Transportation
# 8859      Department of Transportation
# 8860  Illinois Community College Board
# 8861    Department of Military Affairs
#
#                                           Location Name  \
# 0       Anderson Lake Conservation Area - Fulton County
# 1       Anderson Lake Conservation Area - Fulton County
# 2       Anderson Lake Conservation Area - Fulton County
# 3       Anderson Lake Conservation Area - Fulton County
# 4       Anderson Lake Conservation Area - Fulton County
# ...                                                 ...
# 8857  Belvidere Maintenance Storage Facility - Boone...
# ...

# %%
build_group = building.groupby(by=['County',"Agency Name"]).mean("Square Footage")
piv = pd.pivot_table(build_group, values="Square Footage",index=["Agency Name"], columns=["County"])
piv = piv.to_numpy()
piv.shape
np.min(piv), np.nanmin(piv)
# make a heatmap with this data

# 1. data (hist2d & long/lat bins)

# 2. scales
col_sc = bqplot.ColorScale(scheme='RdPu', min=np.nanmin(piv), max=np.nanmax(piv))
x_sc = bqplot.LinearScale() # for numerical data -- longitude
y_sc = bqplot.LinearScale() # numerical data -- latitude

# 3. axis
col_ax = bqplot.ColorAxis(scale=col_sc, orientation='vertical', side='right')
x_ax = bqplot.Axis(scale=x_sc, label='County')
y_ax = bqplot.Axis(scale=y_sc, orientation='vertical', label='Agency Name')

# 4. Marks -- technically a map, but using lat/long as numerical data
heat_map = bqplot.GridHeatMap(color=piv, 
                             scales={'color':col_sc, 'row':y_sc, 'column':x_sc}, 
                             interactions={'click':'select'}, 
                             anchor_style={'fill':'blue'})

# 5. no linking interactivity yet!

# 6. figure!
fig = bqplot.Figure(marks=[heat_map], axes=[col_ax, x_ax, y_ax])
fig
# Out:
# Figure(axes=[ColorAxis(orientation='vertical', scale=ColorScale(max=913236.0, min=100.0, scheme='RdPu'), side=…

# %%
total_square = ufo.groupby(by="Year Acquired")['Square Footage'].agg('sum')
total_square = total_square.drop([0])
total_square = total_square.to_numpy()

# %%
x_sch = bqplot.LinearScale()
y_sch = bqplot.LinearScale()
x_axh = bqplot.Axis(scale=x_sch, label='Year')
y_axh = bqplot.Axis(scale=y_sch, orientation='vertical', label='Square')
histogram = bqplot.Hist(sample = total_square,
                  scales={'sample':x_sch, 'count':y_sch})
figh = bqplot.Figure(marks=[histogram], axes=[x_axh, y_axh])
figh
# Out:
# Figure(axes=[Axis(label='Year', scale=LinearScale()), Axis(label='Square', orientation='vertical', scale=Linea…

# %%
hist.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'apply_clip',
#  'bins',
#  'colors',
#  'count',
#  'display_legend',
#  'enable_hover',
#  'interactions',
#  'labels',
#  'midpoints',
#  'normalized',
#  'opacities',
#  'preserve_domain',
#  'sample',
#  'scales',
#  'scales_metadata',
#  'selected',
#  'selected_style',
#  'stroke',
#  'tooltip',
#  'tooltip_location',
#  'tooltip_style',
#  'unselected_style',
#  'visible']

# %%
hist.sample
# Out:
# array([   1200,    4440,    4033,  120000,   10302,    2010,   11752,
#          36918,    3256,     900,    4088,   65846,   21292,    2267,
#         255000,    2140,   66154,     750,   18124,   22367,    4847,
#          27417,   15795,  223494,    2700,    2864,    6403,   14900,
#          11000,    6600,    3808,  404280,   33071,  179833,    6671,
#          59266,    8725,   30157,  168370,  194823,   84924,   86334,
#           2325,  151480,   39590,   85000,  225677,  290165,  132907,
#          36760,  121475,  335835,  109486,  269725,  160584,   40964,
#         312886,   20374,  133285,  360252,  298283,  231411,  237722,
#         422812,  158710,  334106,  532051,  210013,   32976,   42603,
#          64878,  402059,  187510,  171594,  549360,  126337,  569198,
#        1088997,  637645,  528122,  792329,  841869, 1018630,  414073,
#          68963,  176049,  692530,  663400,  926296, 1113321,  351573,
# ...

# %%
# 1. Data -- data3d

#2. Scales
col_sc = bqplot.ColorScale(scheme="Reds") 
x_sc = bqplot.OrdinalScale() # treating bins like bins of categorical data
y_sc = bqplot.OrdinalScale()

#3. Axis -- color & for x/y
ax_col = bqplot.ColorAxis(scale=col_sc, orientation='vertical', side='right')
ax_x = bqplot.Axis(scale=x_sc)
ax_y = bqplot.Axis(scale=y_sc, orientation='vertical')

# 4. Mark -- heatmap
heat_map = bqplot.GridHeatMap(color=piv,
                             scales={'color':col_sc, 'row':y_sc, 'column':x_sc}, 
                             interactions={'click':'select'}, 
                             anchor_style={'fill':'blue'})

# 5. interactions around here -- in a moment!
mySelectedLabel = ipywidgets.Label()
mySelectedLabel.value = 'Mean selected point here'
# interaction function -- what happens on selection:
def on_selected(change):
    #print(change)
    if len(change['owner'].selected) == 1: # only allow user to select one bin
        i,j = change['owner'].selected[0] # the only selected bin
        print(i,j)
        v = piv.mean() # mean of the 20 points in the 3rd dimension
        mySelectedLabel.value = 'Mean data value='+str(v) # changing the attribute "value" of label widget
        # update histogram based on selection
        hist.sample = piv
# link interaction function to my mark:
heat_map.observe(on_selected, 'selected')

# 6. Finally, put together figure
fig = bqplot.Figure(marks=[heat_map], axes=[ax_col, ax_x, ax_y])

# display!
#fig
myDashboard = ipywidgets.VBox([mySelectedLabel, fig])
myDashboard

# %%
figh
# Out:
# Figure(axes=[Axis(label='Year', scale=LinearScale(), side='bottom'), Axis(label='Square', orientation='vertica…

# %%
# side by side figures
figures = ipywidgets.HBox([fig, figh])

# label on top
myDashboard = ipywidgets.VBox([mySelectedLabel, figures])
myDashboard

# %%
# display all together
# side by side figures
fig.layout.min_width='500px'
figh.layout.min_width = '500px'
figures = ipywidgets.HBox([fig, figh])

# label on top
myDashboard = ipywidgets.VBox([mySelectedLabel, figures])
myDashboard
# Out:
# ...
# 4 25
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# ~\anaconda3\envs\DataViz\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\anaconda3\envs\DataViz\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ...

# %% [markdown]
# Any data transformations or rescalings you did for your plot:
# turned dataframe into array so that I can use to plot
# How you dealt with NaN's (empty entries) in your dataset:
# I dropped them in my dataset, but I also saw articles online that says nan won't be plotted.
# Any aesthetic choices you made (colors, layout, plot size, label size) and why, and what you'd like to experiment with if you had more time:
# First, for my histogram, if I remove scales={'sample':x_sch, 'count':y_sch}, it won't show my plot and I'm not sure why. Also, my dashboard isn't clickable, the two plots aren't liked successfully, but I havend't figured out what caused this problem, also I think I can make the color of them more similar so that they look like a pair.
